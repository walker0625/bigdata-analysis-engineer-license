# %% [markdown]
# # Basic

# %%
import pandas as pd

# %%
color = pd.Series(['빨강', '파랑', '노랑'])
color
# Out:
# 0    빨강
# 1    파랑
# 2    노랑
# dtype: object

# %%
price = pd.Series([1000, 2000, 3000])
price
# Out:
# 0    1000
# 1    2000
# 2    3000
# dtype: int64

# %%
tone = pd.Series([10, 20, 30])
tone
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({
    '색상' : color,
    '가격' : price,
    '톤' : tone
})

df
# Out:
#    색상    가격   톤
# 0  빨강  1000  10
# 1  파랑  2000  20
# 2  노랑  3000  30

# %%
# Series 형태로 선택하는 경우 []
type(df['색상'])
# Out:
# pandas.core.series.Series

# %%
# DataFrame 형태로 선택하는 경우
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame 형태로 선택하는 경우 [[]]
type(df[['색상']])
# Out:
# pandas.core.frame.DataFrame

# %%
# DataFrame 형태로 선택하는 경우 [[]]
type(df[['색상', '가격']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv('test.csv', index=False) # index = False 하지 않으면 index를 별도의 컬럼으로 또 저장함(Unnamed)

# %%
df2 = pd.read_csv('test.csv')
df2.head() # 앞부터
# Out:
#    색상    가격   톤
# 0  빨강  1000  10
# 1  파랑  2000  20
# 2  노랑  3000  30

# %%
df.tail(2) # 마지막
# Out:
#    색상    가격   톤
# 1  파랑  2000  20
# 2  노랑  3000  30

# %%
df.sample(2) # 랜덤 추출
# Out:
#    색상    가격
# 0  빨강  1000
# 1  파랑  2000

# %%
df.shape # (행, 열)
# Out:
# (3, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   색상      3 non-null      object
#  1   가격      3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df.corr(numeric_only=True)
# Out:
#      가격    톤
# 가격  1.0  1.0
# 톤   1.0  1.0

# %%
df.nunique()
# Out:
# 색상    3
# 가격    3
# 톤     3
# dtype: int64

# %%
df['톤'].unique()
# Out:
# array([10, 20, 30])

# %%
df['톤'].value_counts() # s 주의
# Out:
# 톤
# 10    1
# 20    1
# 30    1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            가격     톤
# count     3.0   3.0
# mean   2000.0  20.0
# std    1000.0  10.0
# min    1000.0  10.0
# 25%    1500.0  15.0
# 50%    2000.0  20.0
# 75%    2500.0  25.0
# max    3000.0  30.0

# %%
df.describe(include='O')
# Out:
#         색상
# count    3
# unique   3
# top     빨강
# freq     1

# %%
data = {
    "메뉴": ['아메리카노', '카페라떼', '카페모카', '카푸치노', '에스프레소', '밀크티', '녹차'],
    "가격": [4500.0, 5000.0, 5500.0, 5000.0, 4000.0, 5900.0, 5300.0],
    "칼로리": ['10', '110', '250', '110', '20', '210', '0'],
}
df = pd.DataFrame(data)
df.head()
# Out:
#       메뉴      가격  칼로리
# 0  아메리카노  4500.0   10
# 1   카페라떼  5000.0  110
# 2   카페모카  5500.0  250
# 3   카푸치노  5000.0  110
# 4  에스프레소  4000.0   20

# %%
df.to_csv('cafe.csv', index=False)

# %%
df = pd.read_csv('cafe.csv')
df.head()
# Out:
#       메뉴      가격  칼로리
# 0  아메리카노  4500.0   10
# 1   카페라떼  5000.0  110
# 2   카페모카  5500.0  250
# 3   카푸치노  5000.0  110
# 4  에스프레소  4000.0   20

# %%
df['new'] = 0
df.head()
# Out:
#       메뉴      가격  칼로리  new
# 0  아메리카노  4500.0   10    0
# 1   카페라떼  5000.0  110    0
# 2   카페모카  5500.0  250    0
# 3   카푸치노  5000.0  110    0
# 4  에스프레소  4000.0   20    0

# %%
df['할인가'] = df['가격'] * 0.8
df.head()
# Out:
#       메뉴      가격  칼로리  new     할인가
# 0  아메리카노  4500.0   10    0  3600.0
# 1   카페라떼  5000.0  110    0  4000.0
# 2   카페모카  5500.0  250    0  4400.0
# 3   카푸치노  5000.0  110    0  4000.0
# 4  에스프레소  4000.0   20    0  3200.0

# %%
df = df.drop(0, axis=0)
df.head()
# Out:
#       메뉴      가격  칼로리  new     할인가
# 1   카페라떼  5000.0  110    0  4000.0
# 2   카페모카  5500.0  250    0  4400.0
# 3   카푸치노  5000.0  110    0  4000.0
# 4  에스프레소  4000.0   20    0  3200.0
# 5    밀크티  5900.0  210    0  4720.0

# %%
df = df.drop('칼로리', axis=1)
df.head()
# Out:
#       메뉴      가격  new     할인가
# 1   카페라떼  5000.0    0  4000.0
# 2   카페모카  5500.0    0  4400.0
# 3   카푸치노  5000.0    0  4000.0
# 4  에스프레소  4000.0    0  3200.0
# 5    밀크티  5900.0    0  4720.0

# %%
df.head()
# Out:
#       메뉴      가격  new     할인가
# 1   카페라떼  5000.0    0  4000.0
# 2   카페모카  5500.0    0  4400.0
# 3   카푸치노  5000.0    0  4000.0
# 4  에스프레소  4000.0    0  3200.0
# 5    밀크티  5900.0    0  4720.0

# %%
df.loc[1] # 0은 존재하는 index가 지워져서 조회 불가
# Out:
# 메뉴       카페라떼
# 가격     5000.0
# new         0
# 할인가    4000.0
# Name: 1, dtype: object

# %%
df.iloc[1] # 순서로 조회
# Out:
# 메뉴       카페모카
# 가격     5500.0
# new         0
# 할인가    4400.0
# Name: 2, dtype: object

# %%
df.loc[1, '가격']
# Out:
# np.float64(5000.0)

# %%
df.loc[:, '가격']
# Out:
# 1    5000.0
# 2    5500.0
# 3    5000.0
# 4    4000.0
# 5    5900.0
# 6    5300.0
# Name: 가격, dtype: float64

# %%
df.iloc[0, 1]
# Out:
# np.float64(5000.0)

# %%
df.loc[2:3, 'new':'할인가']
# Out:
#    new     할인가
# 2    0  4400.0
# 3    0  4000.0

# %%
df.iloc[1:3, 1:]
# Out:
#        가격  new     할인가
# 2  5500.0    0  4400.0
# 3  5000.0    0  4000.0

# %%
df.loc[1]
# Out:
# 메뉴       카페라떼
# 가격     5000.0
# new         0
# 할인가    4000.0
# Name: 1, dtype: object

# %%
df.loc[:, '가격']
# Out:
# 1    5000.0
# 2    5500.0
# 3    5000.0
# 4    4000.0
# 5    5900.0
# 6    5300.0
# Name: 가격, dtype: float64

# %%
df.loc[2, '가격':'할인가']
# Out:
# 가격     5500.0
# new         0
# 할인가    4400.0
# Name: 2, dtype: object

# %%
df.loc[2, ['가격', '할인가']]
# Out:
# 가격     5500.0
# 할인가    4400.0
# Name: 2, dtype: object

# %%
df.iloc[0]
# Out:
# 메뉴       카페라떼
# 가격     5000.0
# new         0
# 할인가    4000.0
# Name: 1, dtype: object

# %%
df.iloc[:, 1]
# Out:
# 1    5000.0
# 2    5500.0
# 3    5000.0
# 4    4000.0
# 5    5900.0
# 6    5300.0
# Name: 가격, dtype: float64

# %%
df.iloc[0:2, 1:3]
# Out:
#        가격  new
# 1  5000.0    0
# 2  5500.0    0

# %%
import numpy as np

# %%
df = pd.read_csv('cafe.csv')

# %%
df['원산지'] = None
df.head()
# Out:
#       메뉴      가격  칼로리   원산지
# 0  아메리카노  4500.0   10  None
# 1   카페라떼  5000.0  110  None
# 2   카페모카  5500.0  250  None
# 3   카푸치노  5000.0  110  None
# 4  에스프레소  4000.0   20  None

# %%
df.loc[0, '원산지'] = '콩고'
df.iloc[1, 3] = '과테말라'
df.head()
# Out:
#       메뉴      가격  칼로리   원산지
# 0  아메리카노  4500.0   10    콩고
# 1   카페라떼  5000.0  110  과테말라
# 2   카페모카  5500.0  250  None
# 3   카푸치노  5000.0  110  None
# 4  에스프레소  4000.0   20  None

# %%
df.loc['시즌'] = ['사이다', 1000, 50, '서울']
df.tail()
# Out:
#        메뉴      가격  칼로리   원산지
# 3    카푸치노  5000.0  110  None
# 4   에스프레소  4000.0   20  None
# 5     밀크티  5900.0  210  None
# 6      녹차  5300.0    0  None
# 시즌    사이다  1000.0   50    서울

# %%
df.loc[7] = ['사이다', 1000, 50, '서울']
df.tail()
# Out:
#        메뉴      가격  칼로리   원산지
# 4   에스프레소  4000.0   20  None
# 5     밀크티  5900.0  210  None
# 6      녹차  5300.0    0  None
# 시즌    사이다  1000.0   50    서울
# 7     사이다  1000.0   50    서울

# %%
df.loc[8] = {'메뉴' : '얼박사', '가격' : 3500}
df.tail()
# Out:
#      메뉴      가격    칼로리   원산지
# 5   밀크티  5900.0  210.0  None
# 6    녹차  5300.0    0.0  None
# 시즌  사이다  1000.0   50.0    서울
# 7   사이다  1000.0   50.0    서울
# 8   얼박사  3500.0    NaN   NaN

# %%
df = df.drop('시즌', axis=0)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df = df.drop('시즌', axis=0)
#       2 df.tail()
#
# File c:\walker\code\bigdata-analysis-engineer-license\.venv\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
# ...

# %%
df.to_csv('cafe2.csv', index=False)

# %%
pd.read_csv('cafe2.csv')
# Out:
#       메뉴      가격    칼로리   원산지
# 0  아메리카노  4500.0   10.0    콩고
# 1   카페라떼  5000.0  110.0  과테말라
# 2   카페모카  5500.0  250.0   NaN
# 3   카푸치노  5000.0  110.0   NaN
# 4  에스프레소  4000.0   20.0   NaN
# 5    밀크티  5900.0  210.0   NaN
# 6     녹차  5300.0    0.0   NaN
# 7    사이다  1000.0   50.0    서울
# 8    얼박사  3500.0    NaN   NaN

# %%
df.sort_index(ascending=False)
# Out:
#       메뉴      가격    칼로리   원산지
# 8    얼박사  3500.0    NaN   NaN
# 7    사이다  1000.0   50.0    서울
# 6     녹차  5300.0    0.0   NaN
# 5    밀크티  5900.0  210.0   NaN
# 4  에스프레소  4000.0   20.0   NaN
# 3   카푸치노  5000.0  110.0   NaN
# 2   카페모카  5500.0  250.0   NaN
# 1   카페라떼  5000.0  110.0  과테말라
# 0  아메리카노  4500.0   10.0    콩고

# %%
df.sort_values('가격') # 기본값은 오름차(True)
# Out:
#       메뉴      가격    칼로리   원산지
# 7    사이다  1000.0   50.0    서울
# 8    얼박사  3500.0    NaN   NaN
# 4  에스프레소  4000.0   20.0   NaN
# 0  아메리카노  4500.0   10.0    콩고
# 1   카페라떼  5000.0  110.0  과테말라
# 3   카푸치노  5000.0  110.0   NaN
# 6     녹차  5300.0    0.0   NaN
# 2   카페모카  5500.0  250.0   NaN
# 5    밀크티  5900.0  210.0   NaN

# %%
df = df.sort_values(['가격', '칼로리'], ascending=[True, False])
df
# Out:
#       메뉴      가격    칼로리   원산지
# 7    사이다  1000.0   50.0    서울
# 8    얼박사  3500.0    NaN   NaN
# 4  에스프레소  4000.0   20.0   NaN
# 0  아메리카노  4500.0   10.0    콩고
# 3   카푸치노  5000.0  110.0   NaN
# 1   카페라떼  5000.0  110.0  과테말라
# 6     녹차  5300.0    0.0   NaN
# 2   카페모카  5500.0  250.0   NaN
# 5    밀크티  5900.0  210.0   NaN

# %%
df.reset_index(drop=False)
# Out:
#    index     메뉴      가격    칼로리   원산지
# 0      7    사이다  1000.0   50.0    서울
# 1      8    얼박사  3500.0    NaN   NaN
# 2      4  에스프레소  4000.0   20.0   NaN
# 3      0  아메리카노  4500.0   10.0    콩고
# 4      3   카푸치노  5000.0  110.0   NaN
# 5      1   카페라떼  5000.0  110.0  과테말라
# 6      6     녹차  5300.0    0.0   NaN
# 7      2   카페모카  5500.0  250.0   NaN
# 8      5    밀크티  5900.0  210.0   NaN

# %%
df = df.reset_index(drop=True) # 꼬인 index를 제거
df
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# Name: 가격, dtype: bool

# %%
cond = df['가격'] > 5000 # 조건을 변수화해서 사용하는 것 권장(결과 True/False)
#df[df['가격'] > 3000]
#df[~cond]
df[cond]
# Out:
#      메뉴      가격  칼로리
# 2  카페모카  5500.0  250
# 5   밀크티  5900.0  210
# 6    녹차  5300.0    0

# %%
cond1 = df['가격'] > 3000
cond2 = df['칼로리'] > 100
df[cond1 & cond2]
# Out:
#      메뉴      가격  칼로리
# 1  카페라떼  5000.0  110
# 2  카페모카  5500.0  250
# 3  카푸치노  5000.0  110
# 5   밀크티  5900.0  210

# %%
df[cond1 | cond2]
# Out:
#       메뉴      가격  칼로리
# 0  아메리카노  4500.0   10
# 1   카페라떼  5000.0  110
# 2   카페모카  5500.0  250
# 3   카푸치노  5000.0  110
# 4  에스프레소  4000.0   20
# 5    밀크티  5900.0  210
# 6     녹차  5300.0    0

# %%
cond1 = df['메뉴'] == '녹차'
cond2 = df['가격'] > 6000
# df[(df['메뉴'] == '녹차') &  (df['가격'] > 5000)] => 이렇게 할꺼면 () 처리로 묶어줘야 연산자 우선순위 문제 x
df[cond1 & cond2]
# Out:
# Empty DataFrame
# Columns: [메뉴, 가격, 칼로리]
# Index: []

# %%
menus = ['녹차', '밀크티']
cond = df['메뉴'].isin(menus)
df[cond]
# Out:
#     메뉴      가격  칼로리
# 5  밀크티  5900.0  210
# 6   녹차  5300.0    0

# %%
df = pd.read_csv('cafe2.csv')
df['원산지'] = None
df
# Out:
#       메뉴      가격  칼로리   원산지
# 0  아메리카노  4500.0   10  None
# 1   카페라떼  5000.0  110  None
# 2   카페모카  5500.0  250  None
# 3   카푸치노  5000.0  110  None
# 4  에스프레소  4000.0   20  None
# 5    밀크티  5900.0  210  None
# 6     녹차  5300.0    0  None

# %%
df.loc[0, '원산지'] = '콩고'
df.iloc[1, 3] = '케냐'

# %%
df
# Out:
#       메뉴      가격  칼로리   원산지
# 0  아메리카노  4500.0   10    콩고
# 1   카페라떼  5000.0  110    케냐
# 2   카페모카  5500.0  250  None
# 3   카푸치노  5000.0  110  None
# 4  에스프레소  4000.0   20  None
# 5    밀크티  5900.0  210  None
# 6     녹차  5300.0    0  None

# %%
df['원산지'] = df['원산지'].fillna('한국') # 그냥 df로 대입하면 전체가 한국으로 바뀜

# %%
df
# Out:
#       메뉴      가격  칼로리 원산지
# 0  아메리카노  4500.0   10  콩고
# 1   카페라떼  5000.0  110  케냐
# 2   카페모카  5500.0  250  한국
# 3   카푸치노  5000.0  110  한국
# 4  에스프레소  4000.0   20  한국
# 5    밀크티  5900.0  210  한국
# 6     녹차  5300.0    0  한국

# %%
df.to_csv('cafe3.csv', index=False)

# %%
df = pd.read_csv('cafe3.csv')

# %%
df = df.replace('아메리카노', '루왁')
df
# Out:
#       메뉴      가격  칼로리 원산지
# 0     루왁  4500.0   10  콩고
# 1   카페라떼  5000.0  110  케냐
# 2   카페모카  5500.0  250  한국
# 3   카푸치노  5000.0  110  한국
# 4  에스프레소  4000.0   20  한국
# 5    밀크티  5900.0  210  한국
# 6     녹차  5300.0    0  한국

# %%
df.loc[6, '원산지'] = '일본'
df
# Out:
#       메뉴      가격  칼로리 원산지
# 0     루왁  4500.0   10  콩고
# 1   카페라떼  5000.0  110  케냐
# 2   카페모카  5500.0  250  한국
# 3   카푸치노  5000.0  110  한국
# 4  에스프레소  4000.0   20  한국
# 5    밀크티  5900.0  210  한국
# 6     녹차  5300.0    0  일본

# %%
df.loc[1:2, '이벤트가'] = 2000
df
# Out:
#       메뉴      가격  칼로리 원산지    이벤트가
# 0  아메리카노  4500.0   10  콩고     NaN
# 1   카페라떼  5000.0  110  케냐  2000.0
# 2   카페모카  5500.0  250  한국  2000.0
# 3   카푸치노  5000.0  110  한국     NaN
# 4  에스프레소  4000.0   20  한국     NaN
# 5    밀크티  5900.0  210  한국     NaN
# 6     녹차  5300.0    0  한국     NaN

# %%
df.to_csv('cafe4.csv', index=False)

# %%
df = pd.read_csv('cafe4.csv')
df
# Out:
#       메뉴      가격  칼로리 원산지    이벤트가
# 0  아메리카노  4500.0   10  콩고     NaN
# 1   카페라떼  5000.0  110  케냐  2000.0
# 2   카페모카  5500.0  250  한국  2000.0
# 3   카푸치노  5000.0  110  한국     NaN
# 4  에스프레소  4000.0   20  한국     NaN
# 5    밀크티  5900.0  210  한국     NaN
# 6     녹차  5300.0    0  한국     NaN

# %%
mapping = {'한국' : '국산'}
df['신토불이'] = df['원산지'].map(mapping)
df
# Out:
#       메뉴      가격  칼로리 원산지    이벤트가 신토불이
# 0  아메리카노  4500.0   10  콩고     NaN  NaN
# 1   카페라떼  5000.0  110  케냐  2000.0  NaN
# 2   카페모카  5500.0  250  한국  2000.0   국산
# 3   카푸치노  5000.0  110  한국     NaN   국산
# 4  에스프레소  4000.0   20  한국     NaN   국산
# 5    밀크티  5900.0  210  한국     NaN   국산
# 6     녹차  5300.0    0  한국     NaN   국산

# %%
df = pd.DataFrame({
    'A': ['데이터 분석', '기본 학습서', '퇴근 후 열공'],
    'B': [10, 20, 30],
    'C': ['ab cd', 'AB CD', 'ab cd']
})

df
# Out:
#          A   B      C
# 0   데이터 분석  10  ab cd
# 1   기본 학습서  20  AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A'] = df['A'].str.replace('분석', '시각화') # str이 없으면 전체가 일치해야 바뀜(숫자에 적용하면 오류 발생 주의)

# %%
df
# Out:
#          A   B      C
# 0  데이터 시각화  10  ab cd
# 1   기본 학습서  20  AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['A'].str.split().str[0]
# Out:
# 0    데이터
# 1     기본
# 2     퇴근
# Name: A, dtype: object

# %%
df['A'].str.contains('데이터')
# Out:
# 0     True
# 1    False
# 2    False
# Name: A, dtype: bool

# %%
df
# Out:
#          A   B      C
# 0  데이터 시각화  10  ab cd
# 1   기본 학습서  20  AB CD
# 2  퇴근 후 열공  30  ab cd

# %%
df['C'] = df['C'].str.lower()
df['C'] = df['C'].str.replace(" ", "")
df
# Out:
#          A   B     C
# 0   데이터 분석  10  abcd
# 1   기본 학습서  20  abcd
# 2  퇴근 후 열공  30  abcd

# %%
df['C'].str[1:3] # str 써줘야 일부 추출 없으면 그냥 행을 추출함
# Out:
# 0    bc
# 1    bc
# 2    bc
# Name: C, dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df = pd.read_csv('cafe4.csv')

# %%
cond = df['가격'] > 5000
len(df[cond])
sum(cond)
# Out:
# 3

# %%
df.sum(numeric_only=True)
# Out:
# 가격      35200.0
# 칼로리       710.0
# 이벤트가     4000.0
# dtype: float64

# %%
df
# Out:
#       메뉴      가격  칼로리 원산지    이벤트가
# 0  아메리카노  4500.0   10  콩고     NaN
# 1   카페라떼  5000.0  110  케냐  2000.0
# 2   카페모카  5500.0  250  한국  2000.0
# 3   카푸치노  5000.0  110  한국     NaN
# 4  에스프레소  4000.0   20  한국     NaN
# 5    밀크티  5900.0  210  한국     NaN
# 6     녹차  5300.0    0  한국     NaN

# %%
df.sum(axis=1, numeric_only=True) # sum은 1이 행(drop은 0이 행)
# Out:
# 0    4510.0
# 1    7110.0
# 2    7750.0
# 3    5110.0
# 4    4020.0
# 5    6110.0
# 6    5300.0
# dtype: float64

# %%
cond = df['가격'] > df['가격'].quantile(.90)
df[cond]
# Out:
#     메뉴      가격  칼로리 원산지  이벤트가
# 5  밀크티  5900.0  210  한국   NaN

# %%
df['원산지'].mode()[0]
# Out:
# '한국'

# %%
maxidx = df['가격'].idxmax() # 가장 큰 값의 index 반환
df.loc[maxidx]
# Out:
# 메뉴         밀크티
# 가격      5900.0
# 칼로리        210
# 원산지         한국
# 이벤트가       NaN
# Name: 5, dtype: object

# %%
def cal(x):
    if x >= 100:
        return 'over'
    else:
        return 'under'
    
df['초과'] = df['칼로리'].apply(cal)
df
# Out:
#       메뉴      가격  칼로리 원산지    이벤트가     초과
# 0  아메리카노  4500.0   10  콩고     NaN  under
# 1   카페라떼  5000.0  110  케냐  2000.0   over
# 2   카페모카  5500.0  250  한국  2000.0   over
# 3   카푸치노  5000.0  110  한국     NaN   over
# 4  에스프레소  4000.0   20  한국     NaN  under
# 5    밀크티  5900.0  210  한국     NaN   over
# 6     녹차  5300.0    0  한국     NaN  under

# %%
df = pd.DataFrame({
    'Name': {0: '퀵카', 1: '알파카', 2: '시바견'},
    '수학': {0: 90, 1: 93, 2: 85},
    '영어': {0: 92, 1: 84, 2: 86},
    '국어': {0: 91, 1: 94, 2: 83},
})

df
# Out:
#   Name  수학  영어  국어
# 0   퀵카  90  92  91
# 1  알파카  93  84  94
# 2  시바견  85  86  83

# %%
pd.melt(df, id_vars=['Name'])
# Out:
#   Name variable  value
# 0   퀵카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   퀵카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86
# 6   퀵카       국어     91
# 7  알파카       국어     94
# 8  시바견       국어     83

# %%
pd.melt(df, id_vars=['Name'], value_vars=['수학', '영어'])
# Out:
#   Name variable  value
# 0   퀵카       수학     90
# 1  알파카       수학     93
# 2  시바견       수학     85
# 3   퀵카       영어     92
# 4  알파카       영어     84
# 5  시바견       영어     86

# %%
pd.melt(df, id_vars=['Name'], var_name='과목', value_name='점수')
# Out:
#   Name  과목  점수
# 0   퀵카  수학  90
# 1  알파카  수학  93
# 2  시바견  수학  85
# 3   퀵카  영어  92
# 4  알파카  영어  84
# 5  시바견  영어  86
# 6   퀵카  국어  91
# 7  알파카  국어  94
# 8  시바견  국어  83
